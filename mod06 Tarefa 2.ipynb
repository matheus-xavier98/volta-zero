# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib widget

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
df = pd.read_csv('b1abb33c4f.csv', sep=',')
df.head()

sns.boxplot(data=df, x='IDADEMAE', color='blue')
# Out:
# <Axes: xlabel='IDADEMAE'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sns.boxplot(data=df, x='PESO', color='red')
# Out:
# <Axes: xlabel='PESO'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
sns.histplot(data=df, x='IDADEMAE', color='green')
# Out:
# <Axes: xlabel='IDADEMAE', ylabel='Count'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
sns.histplot(data=df, x='PESO', color='black')
# Out:
# <Axes: xlabel='PESO', ylabel='Count'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
